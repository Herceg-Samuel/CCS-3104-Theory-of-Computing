# %%
import nltk
from nltk.tree import Tree
from nltk.draw import tree
from nltk import CFG
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import nltk
#       2 from nltk.tree import Tree
#       3 from nltk.draw import tree
#
# ModuleNotFoundError: No module named 'nltk'

# %%
grammar4 = CFG.fromstring ("""
S -> NP VP | NP AUX VP
NP -> PROM | NOM | NPR | NPR NOM
NOM -> N | N PP
VP -> TV NP AUX NP | TV NP | IV
AUX -> 'unaweza'| 'ya'
N -> 'ndege' | 'ngari moshi'
TV -> 'kuhifadhi'
PROM -> 'wewe'
NPR -> 'mombasa'
""")

# %%
sent =" wewe unaweza kuhifadhi ndege ya mombasa".split()
rd_parser = nltk.RecursiveDescentParser(grammar4)
for tree in rd_parser.parse(sent):
     print(tree)
# Out:
# (S
#   (NP (PROM wewe))
#   (AUX unaweza)
#   (VP
#     (TV kuhifadhi)
#     (NP (NOM (N ndege)))
#     (AUX ya)
#     (NP (NPR mombasa))))

# %%
nltk.app.rdparser()

# %%
from nltk.grammar import *
grammar4.productions(lhs=Nonterminal("NP"))
# Out:
# [NP -> PROM, NP -> NOM, NP -> NPR, NP -> NPR NOM]

# %%
groucho_grammar = nltk.CFG.fromstring("""
 S -> NP VP
PP -> P NP
NP -> Det N | Det N PP | 'I'
VP -> V NP | VP PP
Det -> 'an' | 'my'
N -> 'elephant' | 'pajamas'
V -> 'shot'
 P -> 'in'
""")

# %%
groucho_grammar.productions(lhs=terminal("Det"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 groucho_grammar.productions(lhs=terminal("Det"))
#
# NameError: name 'terminal' is not defined

# %%
sent = ['I', 'shot', 'an', 'elephant', 'in', 'my', 'pajamas']
parser = nltk.ChartParser(groucho_grammar)
trees = list(parser.parse(sent))
print(trees [1])
# Out:
# (S
#   (NP I)
#   (VP
#     (V shot)
#     (NP (Det an) (N elephant) (PP (P in) (NP (Det my) (N pajamas))))))

# %%
for tree in parser.parse(sent):
      print(tree)
# Out:
# (S
#   (NP I)
#   (VP
#     (VP (V shot) (NP (Det an) (N elephant)))
#     (PP (P in) (NP (Det my) (N pajamas)))))
# (S
#   (NP I)
#   (VP
#     (V shot)
#     (NP (Det an) (N elephant) (PP (P in) (NP (Det my) (N pajamas))))))

# %%
# expect a pop up menu
tree = Tree.fromstring("(S(NP I)(VP(VP (V shot) (NP (Det an) (N elephant)))(PP (P in) (NP (Det my) (N pajamas)))))")
tree.draw()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[16], line 3
#       1 # expect a pop up menu
#       2 tree = Tree.fromstring("(S(NP I)(VP(VP (V shot) (NP (Det an) (N elephant)))(PP (P in) (NP (Det my) (N pajamas)))))")
# ----> 3 tree.draw()
#
# File ~\anaconda3\Lib\site-packages\nltk\tree\tree.py:761, in Tree.draw(self)
#     756 """
#     757 Open a new window containing a graphical diagram of this tree.
#     758 """
#     759 from nltk.draw.tree import draw_trees
# --> 761 draw_trees(self)
#
# File ~\anaconda3\Lib\site-packages\nltk\draw\tree.py:1008, in draw_trees(*trees)
#    1001 def draw_trees(*trees):
#    1002     """
#    1003     Open a new window containing a graphical diagram of the given
#    1004     trees.
#    1005
#    1006     :rtype: None
#    1007     """
# -> 1008     TreeView(*trees).mainloop()
#    1009     return
#
# File ~\anaconda3\Lib\site-packages\nltk\draw\tree.py:998, in TreeView.mainloop(self, *args, **kwargs)
#     996 if in_idle():
#     997     return
# --> 998 self._top.mainloop(*args, **kwargs)
#
# File ~\anaconda3\Lib\tkinter\__init__.py:1485, in Misc.mainloop(self, n)
#    1483 def mainloop(self, n=0):
#    1484     """Call the mainloop of Tk."""
# -> 1485     self.tk.mainloop(n)
#
# KeyboardInterrupt:

# %%
grammar4.start()
# Out:
# S

# %%
grammar4.productions()
# Out:
# [S -> NP VP,
#  S -> NP AUX VP,
#  NP -> PROM,
#  NP -> NOM,
#  NP -> NPR,
#  NP -> NPR NOM,
#  NOM -> N,
#  NOM -> N PP,
#  VP -> TV NP AUX NP,
#  VP -> TV NP,
#  VP -> IV,
#  AUX -> 'unaweza',
#  AUX -> 'ya',
#  N -> 'ndege',
#  N -> 'ngari moshi',
#  TV -> 'kuhifadhi',
#  PROM -> 'wewe',
#  NPR -> 'mombasa']

# %%
grammar1 = CFG.fromstring("""
 S -> A B
 A -> 'a'
 # An empty production:
 B -> 'b' |
 """)

# %%
grammar2 = nltk.CFG.fromstring("""
  S -> NP VP
  VP -> V NP | V NP PP
  PP -> P NP
  V -> "saw" | "ate" | "walked"
  NP -> "John" | "Mary" | "Bob" | Det N | Det N PP
  Det -> "a" | "an" | "the" | "my"
  N -> "man" | "dog" | "cat" | "telescope" | "park"
  P -> "in" | "on" | "by" | "with"
  """)

# %%
sent = "Mary saw Bob".split()
rd_parser = nltk.RecursiveDescentParser(grammar2)
for tree in rd_parser.parse(sent):
     print(tree)
# Out:
# (S (NP Mary) (VP (V saw) (NP Bob)))

# %%
nltk.app.rdparser()
# Out:
# [('under',)]
# [('with',)]
# [('in',)]
# [('under',), ('with',)]
# [('ate',)]
# [('saw',)]
# [('dog',)]
# [('telescope',)]
# [('park',)]
# [('dog',), ('telescope',)]
# [('man',)]
# [('park',), ('dog',), ('telescope',)]
# [('the',)]
# [('a',)]
# [(V, NP)]
# [(V,)]
# [(V, NP, PP)]
# [(V, NP), (V,)]
# [(Det, N, PP)]
# [(Det, N)]
# S [(NP, VP)]
# NP [(Det, N, PP), (Det, N)]
# VP [(V, NP, PP), (V, NP), (V,)]
# PP [(P, NP)]
# NP [('I',)]
# Det [('the',), ('a',)]
# N [('man',), ('park',), ('dog',), ('telescope',)]
# V [('ate',), ('saw',)]
# P [('in',), ('under',), ('with',)]
# [('under',)]
# [('with',)]
# [('in',)]
# [('under',), ('with',)]
# [('saw',)]
# [('ran',)]
# [('ate',)]
# [('saw',), ('ran',)]
# [('telescope',)]
# [('Kimanzi',)]
# [('dog',)]
# [('telescope',), ('Kimanzi',)]
# [('park',)]
# [('dog',), ('telescope',), ('Kimanzi',)]
# [('man',)]
# [('park',), ('dog',), ('telescope',), ('Kimanzi',)]
# [('the',)]
# [('a',)]
# [('I',)]
# [('We',)]
# [(V, NP)]
# [(V,)]
# [(V, NP, PP)]
# [(V, NP), (V,)]
# [(Det, N, PP)]
# [(Det, N)]
# S [(NP, VP)]
# NP [(Det, N, PP), (Det, N)]
# VP [(V, NP, PP), (V, NP), (V,)]
# PP [(P, NP)]
# NP [('I',), ('We',)]
# Det [('the',), ('a',)]
# N [('man',), ('park',), ('dog',), ('telescope',), ('Kimanzi',)]
# V [('ate',), ('saw',), ('ran',)]
# P [('in',), ('under',), ('with',)]
# [('under',)]
# [('with',)]
# [('in',)]
# [('under',), ('with',)]
# [('saw',)]
# [('ran',)]
# [('ate',)]
# [('saw',), ('ran',)]
# [('telescope',)]
# [('Kimanzi',)]
# [('dog',)]
# [('telescope',), ('Kimanzi',)]
# [('park',)]
# [('dog',), ('telescope',), ('Kimanzi',)]
# [('man',)]
# [('park',), ('dog',), ('telescope',), ('Kimanzi',)]
# [('the',)]
# [('a',)]
# [('I',)]
# [('We',)]
# [(V, NP)]
# [(V,)]
# [(V, NP, PP)]
# [(V, NP), (V,)]
# [(Det, N, PP)]
# [(Det, N)]
# S [(NP, VP)]
# NP [(Det, N, PP), (Det, N)]
# VP [(V, NP, PP), (V, NP), (V,)]
# PP [(P, NP)]
# NP [('I',), ('We',)]
# Det [('the',), ('a',)]
# N [('man',), ('park',), ('dog',), ('telescope',), ('Kimanzi',)]
# V [('ate',), ('saw',), ('ran',)]
# P [('in',), ('under',), ('with',)]

# %%
sr_parser = nltk.ShiftReduceParser(grammar2)
sent = 'Mary saw a dog'.split()
for tree in sr_parser.parse(sent):
    print(tree)
# Out:
# (S (NP Mary) (VP (V saw) (NP (Det a) (N dog))))

# %%
nltk.app.chartparser()
# Out:
# grammar= (
# ('    ', 'S -> NP VP,')
# ('    ', 'VP -> VP PP,')
# ('    ', 'VP -> V NP,')
# ('    ', 'VP -> V,')
# ('    ', 'NP -> Det N,')
# ('    ', 'NP -> NP PP,')
# ('    ', 'PP -> P NP,')
# ('    ', "NP -> 'John',")
# ('    ', "NP -> 'I',")
# ('    ', "Det -> 'the',")
# ('    ', "Det -> 'my',")
# ('    ', "Det -> 'a',")
# ('    ', "N -> 'dog',")
# ('    ', "N -> 'cookie',")
# ('    ', "N -> 'table',")
# ('    ', "N -> 'cake',")
# ('    ', "N -> 'fork',")
# ('    ', "V -> 'ate',")
# ('    ', "V -> 'saw',")
# ('    ', "P -> 'on',")
# ('    ', "P -> 'under',")
# ('    ', "P -> 'with',")
# )
# tokens = ['John', 'ate', 'the', 'cake', 'on', 'the', 'table']
# Calling "ChartParserApp(grammar, tokens)"...
# [('under',)]
# [('with',)]
# [('on',)]
# [('under',), ('with',)]
# [('ate',)]
# [('saw',)]
# [('cake',)]
# [('fork',)]
# [('table',)]
# [('cake',), ('fork',)]
# [('cookie',)]
# [('table',), ('cake',), ('fork',)]
# [('dog',)]
# [('cookie',), ('table',), ('cake',), ('fork',)]
# [('my',)]
# [('a',)]
# [('the',)]
# [('my',), ('a',)]
# [('John',)]
# [('I',)]
# [(Det, N)]
# [(NP, PP)]
# [(V, NP)]
# [(V,)]
# [(VP, PP)]
# [(V, NP), (V,)]
# S [(NP, VP)]
# VP [(VP, PP), (V, NP), (V,)]
# NP [(Det, N), (NP, PP)]
# PP [(P, NP)]
# NP [('John',), ('I',)]
# Det [('the',), ('my',), ('a',)]
# N [('dog',), ('cookie',), ('table',), ('cake',), ('fork',)]
# V [('ate',), ('saw',)]
# P [('on',), ('under',), ('with',)]
